# %%
# Insert code here.
import argparse
import sqlite3
import pandas as pd
from tqdm import tqdm

# %%
path = '/datasets/nela-gt/nela-eng-2019.db'
conn = sqlite3.connect(path)

# %%
def execute_query(conn, query):
    # execute query on database and retrieve them with fetchall
    results = conn.cursor().execute(query).fetchall()
    return results

# %%
path = '/datasets/nela-gt/labels.csv'
labels = dict()
with open(path) as fin:
    # Read out the header line from label file
    fin.readline()
    # Iterate over lines, taking the value from first column after name
    # i.e., aggregated label
    for line in fin:
        l = line.strip().split(",")
        source = l[0]
        if l[1] == "":  # NODATA for this entry, skip it
            continue
        labels[source] = int(l[1])  # get value from last column (label)

# %%
len(labels)
# Out:
# 183

# %%
execute_query(conn, "SELECT * FROM sqlite_master WHERE type = 'table'")
# Out:
# [('table',
#   'newsdata',
#   'newsdata',
#   2,
#   'CREATE TABLE newsdata (id text primary key,date text,source text,title text,content text,author text,url text,published text,published_utc integer,collection_utc integer)')]

# %%
total_no_sources = execute_query(conn, "SELECT distinct source FROM newsdata")
len(total_no_sources)
# Out:
# 261

# %%
total_no_sources
# Out:
# [('thenewyorktimes',),
#  ('businessinsider',),
#  ('skynewsus',),
#  ('themichellemalkinblog',),
#  ('cnbc',),
#  ('channel4uk',),
#  ('msnbc',),
#  ('thedailyblog',),
#  ('delawareliberal',),
#  ('theindependent',),
#  ('foxnews',),
#  ('newsweek',),
#  ('realnewsrightnow',),
#  ('tass',),
#  ('thinkprogress',),
#  ('thedcclothesline',),
#  ('sluggerotoole',),
#  ('spiegel',),
#  ('sottnet',),
#  ('motherjones',),
#  ('theweekuk',),
#  ('bbcuk',),
#  ('eveningstandard',),
#  ('aljazeera',),
#  ('prisonplanet',),
#  ('adobochronicles',),
#  ('newsbiscuit',),
#  ('conservativetribune',),
#  ('liveaction',),
#  ('powerlineblog',),
#  ('themoscowtimes',),
#  ('veteranstoday',),
#  ('hullabalooblog',),
#  ('thedailymirror',),
#  ('talkingpointsmemo',),
#  ('activistpost',),
#  ('renegadetribune',),
#  ('washingtonmonthly',),
#  ('theblaze',),
#  ('collectiveevolution',),
#  ('crooksandliars',),
#  ('thehuffingtonpost',),
#  ('prepareforchange',),
#  ('mintpressnews',),
#  ('fusion',),
#  ('infowars',),
#  ('frontpagemagazine',),
#  ('ipolitics',),
#  ('wingsoverscotland',),
#  ('thedenverpost',),
#  ('palmerreport',),
#  ('thefiscaltimes',),
#  ('thesun',),
#  ('newspunch',),
#  ('thetelegraph',),
#  ('politico',),
#  ('fortruss',),
#  ('therightscoop',),
#  ('shareblue',),
#  ('unian',),
#  ('thevaccinereaction',),
#  ('dailykos',),
#  ('trueactivist',),
#  ('bipartisanreport',),
#  ('newyorker',),
#  ('pbs',),
#  ('anonymousconservative',),
#  ('rawstory',),
#  ('sputnik',),
#  ('birminghammail',),
#  ('abcnews',),
#  ('thedailyrecord',),
#  ('hitandrun',),
#  ('realclearpolitics',),
#  ('wsjwashingtonwire',),
#  ('hotair',),
#  ('thegatewaypundit',),
#  ('bearingarms',),
#  ('21stcenturywire',),
#  ('theverge',),
#  ('russiainsider',),
#  ('themanchestereveningnews',),
#  ('cnn',),
#  ('thebeaverton',),
#  ('nationalreview',),
#  ('thepoliticalinsider',),
#  ('windowoneurasiablog',),
#  ('usatoday',),
#  ('redstate',),
#  ('oann',),
#  ('theirishtimes',),
#  ('glossynews',),
#  ('intellihub',),
#  ('theintercept',),
#  ('globalresearch',),
#  ('pravadareport',),
#  ('mercurynews',),
#  ('crikey',),
#  ('liberaldemocratvoice',),
#  ('politicalite',),
#  ('thedailyecho',),
#  ('theborowitzreport',),
#  ('newyorkpost',),
#  ('westernjournal',),
#  ('reuters',),
#  ('theonion',),
#  ('theconservativetreehouse',),
#  ('theduran',),
#  ('thepoke',),
#  ('humansarefree',),
#  ('chicagosuntimes',),
#  ('wakingtimes',),
#  ('politicususa',),
#  ('inquisitr',),
#  ('yahoonews',),
#  ('fortune',),
#  ('drudgereport',),
#  ('democracy21',),
#  ('mediamattersforamerica',),
#  ('dickmorrisblog',),
#  ('observer',),
#  ('theguardian',),
#  ('jewworldorder',),
#  ('thehuffingtonpostuk',),
#  ('newswars',),
#  ('buzzfeed',),
#  ('theatlantic',),
#  ('instapundit',),
#  ('thedailybeast',),
#  ('therussophileorg',),
#  ('theamericanconservative',),
#  ('vox',),
#  ('rt',),
#  ('lewrockwell',),
#  ('labourlist',),
#  ('france24',),
#  ('ftwestminsterblog',),
#  ('cbsnews',),
#  ('naturalnews',),
#  ('thedailyexpress',),
#  ('npr',),
#  ('pinknewsuk',),
#  ('theantimedia',),
#  ('skynewspolitics',),
#  ('thespoof',),
#  ('anonnews',),
#  ('ageofautism',),
#  ('freedomoutpost',),
#  ('foreignpolicy',),
#  ('freedombunker',),
#  ('dailysignal',),
#  ('newsbusters',),
#  ('thedailycaller',),
#  ('breitbart',),
#  ('bbc',),
#  ('rightwingwatch',),
#  ('rferl',),
#  ('fivethirtyeight',),
#  ('cnsnews',),
#  ('theguardianuk',),
#  ('conservativehome',),
#  ('truepundit',),
#  ('thehill',),
#  ('mail',),
#  ('osce',),
#  ('coloradopeakpolitics',),
#  ('politicalwire',),
#  ('humortimes',),
#  ('bizstandardnews',),
#  ('dailymail',),
#  ('dcgazette',),
#  ('intellectualconservative',),
#  ('pamelagellerreport',),
#  ('thedailystar',),
#  ('slate',),
#  ('urbanintellectuals',),
#  ('theseattletimes',),
#  ('politicscouk',),
#  ('trumptimes',),
#  ('latimes',),
#  ('thetorontostar',),
#  ('dailyheraldchicago',),
#  ('politicsuk',),
#  ('newsnetscotland',),
#  ('antiimpreialist',),
#  ('informnapalm',),
#  ('vaxxter',),
#  ('wizbang',),
#  ('shadowproof',),
#  ('turningpointusa',),
#  ('thevalleyreport',),
#  ('americablognews',),
#  ('theshovel',),
#  ('investorsbusinessdaily',),
#  ('feministingblog',),
#  ('addictinginfo',),
#  ('nationalreport',),
#  ('dailystormer',),
#  ('theepochtimes',),
#  ('occupydemocrats',),
#  ('shtfplan',),
#  ('clashdaily',),
#  ('breaking911',),
#  ('vdare',),
#  ('thewashingtonstandard',),
#  ('remnantnewspaper',),
#  ('newslo',),
#  ('telesurtv',),
#  ('personalliberty',),
#  ('interpretermag',),
#  ('unconfirmedsources',),
#  ('salon',),
#  ('hangthebankers',),
#  ('dailybuzzlive',),
#  ('liberaladvocate',),
#  ('now8news',),
#  ('baltimoregazette',),
#  ('dailybeast',),
#  ('washingtonpost',),
#  ('chicagotribune',),
#  ('newyorkdailynews',),
#  ('lifesitenews',),
#  ('democracynow',),
#  ('zerohedge',),
#  ('airwars',),
#  ('thehuffingtonpostpoliticalsatire',),
#  ('newsyoucantuse',),
#  ('nationalinterest',),
#  ('wnd',),
#  ('greenwichtime',),
#  ('charlotteobserver',),
#  ('csmonitor',),
#  ('freebeacon',),
#  ('jerusalempost',),
#  ('newsmax',),
#  ('rollcall',),
#  ('thesmokinggun',),
#  ('usnews',),
#  ('yna',),
#  ('mcclatchydc',),
#  ('upi',),
#  ('obamawatcher',),
#  ('thewashingtonexaminer',),
#  ('deneenborelli',),
#  ('environmentdepth',),
#  ('thechaser',),
#  ('civictribune',),
#  ('thelibertydaily',),
#  ('thecollegefix',),
#  ('citizenfreepress',),
#  ('noqreport',),
#  ('bigleaguepolitics',),
#  ('disrn',),
#  ('camelotdaily',),
#  ('newsbud',),
#  ('lisahaven',),
#  ('saraacater',),
#  ('bonginoreport',),
#  ('warroom',),
#  ('therealnews',),
#  ('anti-impreialist',)]

# %%
each_source_counts = execute_query(conn, "SELECT source, count(source) FROM newsdata group by source")

# %%
each_source_counts
# Out:
# [('21stcenturywire', 791),
#  ('abcnews', 2861),
#  ('activistpost', 2780),
#  ('addictinginfo', 12),
#  ('adobochronicles', 417),
#  ('ageofautism', 646),
#  ('airwars', 16),
#  ('aljazeera', 11611),
#  ('americablognews', 104),
#  ('anonnews', 508),
#  ('anonymousconservative', 386),
#  ('anti-impreialist', 11),
#  ('antiimpreialist', 23),
#  ('baltimoregazette', 1),
#  ('bbc', 14522),
#  ('bbcuk', 12211),
#  ('bearingarms', 1902),
#  ('bigleaguepolitics', 131),
#  ('bipartisanreport', 4175),
#  ('birminghammail', 16864),
#  ('bizstandardnews', 149),
#  ('bonginoreport', 221),
#  ('breaking911', 638),
#  ('breitbart', 7431),
#  ('businessinsider', 737),
#  ('buzzfeed', 1741),
#  ('camelotdaily', 17),
#  ('cbsnews', 6758),
#  ('channel4uk', 2591),
#  ('charlotteobserver', 1793),
#  ('chicagosuntimes', 2795),
#  ('chicagotribune', 1887),
#  ('citizenfreepress', 318),
#  ('civictribune', 1),
#  ('clashdaily', 1078),
#  ('cnbc', 2962),
#  ('cnn', 7766),
#  ('cnsnews', 7204),
#  ('collectiveevolution', 707),
#  ('coloradopeakpolitics', 296),
#  ('conservativehome', 2990),
#  ('conservativetribune', 980),
#  ('crikey', 825),
#  ('crooksandliars', 3009),
#  ('csmonitor', 108),
#  ('dailybeast', 1937),
#  ('dailybuzzlive', 27),
#  ('dailyheraldchicago', 4222),
#  ('dailykos', 807),
#  ('dailymail', 4413),
#  ('dailysignal', 511),
#  ('dailystormer', 253),
#  ('dcgazette', 1335),
#  ('delawareliberal', 1250),
#  ('democracy21', 100),
#  ('democracynow', 267),
#  ('deneenborelli', 60),
#  ('dickmorrisblog', 500),
#  ('disrn', 246),
#  ('drudgereport', 16449),
#  ('environmentdepth', 37),
#  ('eveningstandard', 37427),
#  ('feministingblog', 7),
#  ('fivethirtyeight', 877),
#  ('foreignpolicy', 2313),
#  ('fortruss', 2600),
#  ('fortune', 7813),
#  ('foxnews', 5599),
#  ('france24', 4375),
#  ('freebeacon', 570),
#  ('freedombunker', 5501),
#  ('freedomoutpost', 677),
#  ('frontpagemagazine', 1048),
#  ('ftwestminsterblog', 146),
#  ('fusion', 1070),
#  ('globalresearch', 5361),
#  ('glossynews', 117),
#  ('greenwichtime', 282),
#  ('hangthebankers', 5),
#  ('hitandrun', 4698),
#  ('hotair', 5421),
#  ('hullabalooblog', 2441),
#  ('humansarefree', 1031),
#  ('humortimes', 393),
#  ('informnapalm', 126),
#  ('infowars', 2442),
#  ('inquisitr', 4126),
#  ('instapundit', 19396),
#  ('intellectualconservative', 598),
#  ('intellihub', 288),
#  ('interpretermag', 20),
#  ('investorsbusinessdaily', 184),
#  ('ipolitics', 2634),
#  ('jerusalempost', 1789),
#  ('jewworldorder', 2609),
#  ('labourlist', 1351),
#  ('latimes', 2875),
#  ('lewrockwell', 2874),
#  ('liberaladvocate', 3),
#  ('liberaldemocratvoice', 1638),
#  ('lifesitenews', 932),
#  ('lisahaven', 20),
#  ('liveaction', 1860),
#  ('mail', 14121),
#  ('mcclatchydc', 514),
#  ('mediamattersforamerica', 1574),
#  ('mercurynews', 8107),
#  ('mintpressnews', 735),
#  ('motherjones', 1720),
#  ('msnbc', 6695),
#  ('nationalinterest', 3211),
#  ('nationalreport', 4),
#  ('nationalreview', 4560),
#  ('naturalnews', 4376),
#  ('newsbiscuit', 1765),
#  ('newsbud', 21),
#  ('newsbusters', 6308),
#  ('newslo', 27),
#  ('newsmax', 1342),
#  ('newsnetscotland', 60),
#  ('newspunch', 2460),
#  ('newswars', 8814),
#  ('newsweek', 3854),
#  ('newsyoucantuse', 20),
#  ('newyorkdailynews', 66),
#  ('newyorker', 4427),
#  ('newyorkpost', 15438),
#  ('noqreport', 126),
#  ('now8news', 1),
#  ('npr', 5650),
#  ('oann', 8620),
#  ('obamawatcher', 35),
#  ('observer', 405),
#  ('occupydemocrats', 649),
#  ('osce', 1416),
#  ('palmerreport', 4255),
#  ('pamelagellerreport', 992),
#  ('pbs', 3171),
#  ('personalliberty', 32),
#  ('pinknewsuk', 3779),
#  ('politicalite', 1114),
#  ('politicalwire', 3916),
#  ('politico', 2388),
#  ('politicscouk', 318),
#  ('politicsuk', 229),
#  ('politicususa', 4048),
#  ('powerlineblog', 1932),
#  ('pravadareport', 604),
#  ('prepareforchange', 1501),
#  ('prisonplanet', 6668),
#  ('rawstory', 10840),
#  ('realclearpolitics', 8171),
#  ('realnewsrightnow', 29),
#  ('redstate', 6859),
#  ('remnantnewspaper', 59),
#  ('renegadetribune', 1782),
#  ('reuters', 5120),
#  ('rferl', 4962),
#  ('rightwingwatch', 1023),
#  ('rollcall', 875),
#  ('rt', 3210),
#  ('russiainsider', 1868),
#  ('salon', 4),
#  ('saraacater', 59),
#  ('shadowproof', 247),
#  ('shareblue', 2373),
#  ('shtfplan', 369),
#  ('skynewspolitics', 2269),
#  ('skynewsus', 2101),
#  ('slate', 6328),
#  ('sluggerotoole', 960),
#  ('sottnet', 16741),
#  ('spiegel', 9173),
#  ('sputnik', 35418),
#  ('talkingpointsmemo', 4129),
#  ('tass', 16914),
#  ('telesurtv', 367),
#  ('theamericanconservative', 602),
#  ('theantimedia', 911),
#  ('theatlantic', 1349),
#  ('thebeaverton', 744),
#  ('theblaze', 7320),
#  ('theborowitzreport', 115),
#  ('thechaser', 88),
#  ('thecollegefix', 66),
#  ('theconservativetreehouse', 2581),
#  ('thedailybeast', 6004),
#  ('thedailyblog', 491),
#  ('thedailycaller', 11990),
#  ('thedailyecho', 7556),
#  ('thedailyexpress', 4521),
#  ('thedailymirror', 21085),
#  ('thedailyrecord', 13585),
#  ('thedailystar', 134),
#  ('thedcclothesline', 2976),
#  ('thedenverpost', 7405),
#  ('theduran', 2911),
#  ('theepochtimes', 2830),
#  ('thefiscaltimes', 821),
#  ('thegatewaypundit', 7446),
#  ('theguardian', 3005),
#  ('theguardianuk', 36739),
#  ('thehill', 4434),
#  ('thehuffingtonpost', 6538),
#  ('thehuffingtonpostpoliticalsatire', 1),
#  ('thehuffingtonpostuk', 7564),
#  ('theindependent', 43469),
#  ('theintercept', 1194),
#  ('theirishtimes', 8737),
#  ('thelibertydaily', 257),
#  ('themanchestereveningnews', 16409),
#  ('themichellemalkinblog', 72),
#  ('themoscowtimes', 2959),
#  ('thenewyorktimes', 6510),
#  ('theonion', 2301),
#  ('thepoke', 3441),
#  ('thepoliticalinsider', 3882),
#  ('therealnews', 51),
#  ('therightscoop', 2816),
#  ('therussophileorg', 81921),
#  ('theseattletimes', 7706),
#  ('theshovel', 272),
#  ('thesmokinggun', 125),
#  ('thespoof', 1335),
#  ('thesun', 72974),
#  ('thetelegraph', 30373),
#  ('thetorontostar', 7291),
#  ('thevaccinereaction', 243),
#  ('thevalleyreport', 41),
#  ('theverge', 4855),
#  ('thewashingtonexaminer', 1072),
#  ('thewashingtonstandard', 927),
#  ('theweekuk', 4521),
#  ('thinkprogress', 2210),
#  ('trueactivist', 281),
#  ('truepundit', 12672),
#  ('trumptimes', 539),
#  ('turningpointusa', 3),
#  ('unconfirmedsources', 7),
#  ('unian', 7747),
#  ('upi', 2444),
#  ('urbanintellectuals', 126),
#  ('usatoday', 6061),
#  ('usnews', 10354),
#  ('vaxxter', 158),
#  ('vdare', 993),
#  ('veteranstoday', 1860),
#  ('vox', 3804),
#  ('wakingtimes', 896),
#  ('warroom', 99),
#  ('washingtonmonthly', 1135),
#  ('washingtonpost', 1462),
#  ('westernjournal', 10814),
#  ('windowoneurasiablog', 2279),
#  ('wingsoverscotland', 276),
#  ('wizbang', 244),
#  ('wnd', 1002),
#  ('wsjwashingtonwire', 99),
#  ('yahoonews', 2220),
#  ('yna', 1848),
#  ('zerohedge', 2379)]

# %%
len(labels.keys())
# Out:
# 183

# %%
counts_dict = {}
for each_source in each_source_counts:
    if each_source[0] in labels:
        type_ = labels[each_source[0]]
        if type_ in counts_dict:
            counts_dict[type_] += each_source[1]
        else:
            counts_dict[type_] = each_source[1]
    else:
        print(each_source[0])
counts_dict
# Out:
# adobochronicles
# anonnews
# anonymousconservative
# anti-impreialist
# antiimpreialist
# baltimoregazette
# bizstandardnews
# camelotdaily
# channel4uk
# civictribune
# coloradopeakpolitics
# conservativehome
# conservativetribune
# crikey
# delawareliberal
# deneenborelli
# dickmorrisblog
# disrn
# environmentdepth
# fortruss
# freedombunker
# freedomoutpost
# ftwestminsterblog
# glossynews
# greenwichtime
# hitandrun
# hullabalooblog
# humortimes
# informnapalm
# inquisitr
# instapundit
# intellectualconservative
# jewworldorder
# labourlist
# liberaldemocratvoice
# lisahaven
# mail
# nationalreport
# newsbiscuit
# newslo
# newsnetscotland
# newsyoucantuse
# now8news
# obamawatcher
# osce
# politicalite
# politicscouk
# politicsuk
# prepareforchange
# realnewsrightnow
# renegadetribune
# saraacater
# sluggerotoole
# thebeaverton
# theborowitzreport
# thechaser
# thedailyblog
# thedailyecho
# thehuffingtonpostpoliticalsatire
# themanchestereveningnews
# themichellemalkinblog
# theonion
# thepoke
# therussophileorg
# theshovel
# thespoof
# thevaccinereaction
# thevalleyreport
# thewashingtonstandard
# theweekuk
# trumptimes
# unconfirmedsources
# unian
# urbanintellectuals
# warroom
# windowoneurasiablog
# wizbang
# yna
# {2: 126009, 0: 446251, 1: 331746}

# %%
percent = 10
sample_sizes = []
for x in [0,2]:
    count = counts_dict[x]
    source_counts = [each for each in each_source_counts if each[0] in labels and labels[each[0]] == x]
    source_distribution = { each[0]: each[1]/count for each in source_counts}
    sampling_10 = int(count * (percent /100))
    sample_sizes += [(each , int(source_distribution[each] * sampling_10)) for each in source_distribution.keys() if int(source_distribution[each] * sampling_10)  != 0 ]

# %%
sampled_data = []
for src in tqdm(sample_sizes):
    res = execute_query(conn, "select * from newsdata where source ='" + src[0] + "' limit " + str(src[1]))
    sampled_data = sampled_data + res
# Out:
#  19%|█▉        | 25/129 [00:23<01:08,  1.52it/s]
# 100%|██████████| 129/129 [01:23<00:00,  1.54it/s]

# %%
sampled_df = pd.DataFrame(sampled_data, columns=["id" ,"date" ,"source" ,"title" ,"content" ,"author" ,"url" ,"published" ,"published_utc" ,"collection_utc"])

# %%
label_mapping = {0:"Reliable", 1 : "Mixed", 2: "Unreliable"}

# %%
sampled_df["source"].map(labels).value_counts()
# Out:
# 0    44582
# 2    12575
# Name: source, dtype: int64

# %%
sampled_df["Reliability"] = sampled_df["source"].map(labels)

# %%
sampled_df.sample(10)

# %%
sampled_df.to_csv(path_or_buf='../datasets/nela10.csv', index=False)
